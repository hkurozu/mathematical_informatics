# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df1 = pd.read_csv('/Users/kurozuhajime/Desktop/Mathematical Optimization/JSScheduling/data/SIM_100_20.csv')
df2 = pd.read_csv('/Users/kurozuhajime/Desktop/Mathematical Optimization/JSScheduling/data/SIM_10_10.csv')
df3 = pd.read_csv('/Users/kurozuhajime/Desktop/Mathematical Optimization/JSScheduling/data/SIM_20_5.csv')
#df4 = pd.read_csv('/Users/kurozuhajime/Desktop/JSScheduling/data/SIM_8_8.csv')


#print(df2)
plt.plot(df1['SIM_No'], df1['P_1']/df1['P_3'], color='b')
plt.plot(df1['SIM_No'], df1['P_2']/df1['P_3'], color='r')
plt.plot(df1['SIM_No'], df1['P_3']/df1['P_3'], color='orange')
plt.ylim(0.9, 1.3)
plt.show()

plt.plot(df2['SIM_No'], df2['P_1']/df2['P_3'], color='b')
plt.plot(df2['SIM_No'], df2['P_2']/df2['P_3'], color='r')
plt.plot(df2['SIM_No'], df2['P_3']/df2['P_3'], color='orange')
plt.ylim(0.8, 1.1)
plt.show()

plt.plot(df3['SIM_No'], df3['P_1']/df3['P_3'], color='b')
plt.plot(df3['SIM_No'], df3['P_2']/df3['P_3'], color='r')
plt.plot(df3['SIM_No'], df3['P_3']/df3['P_3'], color='orange')
plt.ylim(0.9, 1.3)
plt.show()


#plt.plot(df4['SIM_No'], df4['P_1']/df4['P_3'], linewidth=3, color='b')
#plt.plot(df4['SIM_No'], df4['P_2']/df4['P_3'], color='r')
#plt.plot(df4['SIM_No'], df4['P_3']/df4['P_3'], color='orange')
#plt.ylim(0.9, 1.3)
#plt.show()
